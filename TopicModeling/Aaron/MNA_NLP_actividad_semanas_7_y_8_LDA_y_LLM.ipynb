# %% [markdown]
# # **Procesamiento de Lenguaje Natural**
#
# ## Maestría en Inteligencia Artificial Aplicada
# #### Tecnológico de Monterrey
# #### Prof Luis Eduardo Falcón Morales
#
# ### **Adtividad en Equipos Semanas 7 y 8 : LDA y LMM audio-a-texto**

# %% [markdown]
# * **Nombres y matrículas:**
#
#   *   Elemento de lista
#   *   Elemento de lista
#   *   Elemento de lista
#
# * **Número de Equipo:**

# %% [markdown]
# * ##### **En cada ejercicio pueden importar los paquetes o librerías que requieran.**
#
# * ##### **En cada ejercicio pueden incluir las celdas y líneas de código que deseen.**

# %%
# !pip install transformers accelerate
#!apt-get install -y ffmpeg   # si trabajas en tu computadora necesitarás FFMPEG para manejo de archivos de audio y música
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.3)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.32.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 29.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 24.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 15.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 43.7 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %% [markdown]
# # **Ejercicio 1:**

# %% [markdown]
# * #### **Liga de los audios de las fábulas de Esopo:** https://www.gutenberg.org/ebooks/21144
#
# * #### **Descargar los 10 archivos de audio solicitados: 1, 4, 5, 6, 14, 22, 24, 25, 26, 27.**

# %%
# Incluyan a continuación todas las celdas (de código o texto) que deseen...
# !pip install numpy==1.25.2 scipy==1.11.3 gensim==4.3.2 --force-reinstall --upgrade
import torch
from transformers import pipeline
from transformers import AutoProcessor, AutoModelForSpeechSeq2Seq
import librosa   # paquete para audio y música
import warnings
# para filtrar advertencias:
warnings.filterwarnings("ignore")

# Descargamos todos los archivos de una:
# !wget -N https://www.gutenberg.org/files/21144/mp3/21144-{01,04,05,06,14,22,24,25,26,27}.mp3
# Out:
# Collecting numpy==1.25.2
#   Using cached numpy-1.25.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting scipy==1.11.3
#   Using cached scipy-1.11.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting gensim==4.3.2
#   Using cached gensim-4.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Collecting smart-open>=1.8.1 (from gensim==4.3.2)
#   Using cached smart_open-7.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart-open>=1.8.1->gensim==4.3.2)
#   Using cached wrapt-1.17.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Using cached numpy-1.25.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Using cached scipy-1.11.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.4 MB)
# Using cached gensim-4.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
# Using cached smart_open-7.1.0-py3-none-any.whl (61 kB)
# Using cached wrapt-1.17.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (83 kB)
# Installing collected packages: wrapt, numpy, smart-open, scipy, gensim
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.2
#     Uninstalling wrapt-1.17.2:
#       Successfully uninstalled wrapt-1.17.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 7.1.0
#     Uninstalling smart-open-7.1.0:
#       Successfully uninstalled smart-open-7.1.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.3
#     Uninstalling scipy-1.11.3:
#       Successfully uninstalled scipy-1.11.3
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.3.2
#     Uninstalling gensim-4.3.2:
#       Successfully uninstalled gensim-4.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# blosc2 3.3.4 requires numpy>=1.26, but you have numpy 1.25.2 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.25.2 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.11.3 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.25.2 which is incompatible.
# scikit-image 0.25.2 requires scipy>=1.11.4, but you have scipy 1.11.3 which is incompatible.
# Successfully installed gensim-4.3.2 numpy-1.25.2 scipy-1.11.3 smart-open-7.1.0 wrapt-1.17.2

# %%
import os
archivos = [f for f in os.listdir(".") if f.endswith(".mp3")]

# Mostrar duraciones
for archivo in sorted(archivos):
    audio, sample_rate = librosa.load(archivo)
    duracion = len(audio) / sample_rate
    print(f"{archivo}: {duracion:.1f} segundos")
# Out:
# 21144-01.mp3: 72.6 segundos
# 21144-04.mp3: 67.1 segundos
# 21144-05.mp3: 58.4 segundos
# 21144-06.mp3: 71.8 segundos
# 21144-14.mp3: 58.1 segundos
# 21144-22.mp3: 57.2 segundos
# 21144-24.mp3: 64.5 segundos
# 21144-25.mp3: 56.5 segundos
# 21144-26.mp3: 63.7 segundos
# 21144-27.mp3: 60.3 segundos

# %% [markdown]
# # **Ejercicio 2a:**

# %% [markdown]
# * #### **Comenten el por qué del modelo seleccionado para extracción del texto de los audios.**
#
# * #### **Extraer el contenido de los audios en texto.**
#
# * #### **Sugerencia:** pueden extraerlo en un formato de diccionario, clave:valor $→$ {audio01:fabula01, ...}

# %%
# Buscando usar GPU
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Usando dispositivo: {device}")
# Out:
# Usando dispositivo: cpu

# %% [markdown]
# ### Selección del modelo de Whisper a usar #####
# En este caso en particular he decidido comenzar con el modelo whisper-large-v3 porque es el modelo mas completo que hay. Si bien se tiene el modelo turbo, esa velocidad de entrega podría comprometer en algo los resultados.
#
# Por ello decidí tomar el mas lento pero que me asegure la mayor precisión en los resultados.
#
# Posiblemente luego corra todo con el modelo turbo para ver la diferencia en los resultados.

# %%
# Llamar al modelo de whisper large-v3 para mejor precisión
model_id = "openai/whisper-large-v3"    # mejor modelo

# Cargamos el modelo:
processor = AutoProcessor.from_pretrained(model_id)
modelo = AutoModelForSpeechSeq2Seq.from_pretrained(model_id).to(device)
# Out:
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.07k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.90k [00:00<?, ?B/s]

# %%
# Creamos el pipeline para el reconocimiento de voz
pipe = pipeline("automatic-speech-recognition",
    model=modelo,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
    device=device
    )
# Out:
# Device set to use cpu

# %%
# Extraemos el texto de todos los audios:
transcripciones = {}

# Procesar cada audio
archivos_mp3 = sorted([f for f in os.listdir(".") if f.endswith(".mp3")])
for archivo in archivos_mp3:
    ruta_audio = archivo
    print(f"Procesando {archivo}...")

    audio, sr = librosa.load(ruta_audio)
    result = pipe(audio,
      return_timestamps=True,
      generate_kwargs={"language": "es"}
    )

    transcripciones[archivo] = result["text"]

for nombre, texto in transcripciones.items():
    print(f"\n {nombre}:\n{texto}\n")
# Out:
# Procesando 21144-01.mp3...
# You have passed language=es, but also have set `forced_decoder_ids` to [[1, None], [2, 50360]] which creates a conflict. `forced_decoder_ids` will be ignored in favor of language=es.
# Procesando 21144-04.mp3...
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Procesando 21144-05.mp3...
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Procesando 21144-06.mp3...
# Procesando 21144-14.mp3...
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Procesando 21144-22.mp3...
# Procesando 21144-24.mp3...
# Procesando 21144-25.mp3...
# Procesando 21144-26.mp3...
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Procesando 21144-27.mp3...
#
#  21144-01.mp3:
#  Las fábulas de Sopo Grabado para LibriVox.org por Paulino www.paulino.info Fábula número 61 El lobo y el cordero en el templo Dándose cuenta de que era perseguido por un lobo, un pequeño corderito decidió refugiarse en un templo cercano. Lo llamó lobo y le dijo que si el sacrificador lo encontraba allí adentro, lo inmolaría a su dios. Mejor así, replicó el cordero. Prefiero ser víctima para un dios a tener que perecer en tus colmillos. Si sin remedio vamos a ser sacrificados, más nos vale que sea con el mayor honor. Fin de la fábula. Esta es una grabación del dominio público. Gracias por ver el video.
#
#
#  21144-04.mp3:
#  Las fábulas de Esopo grabado para LibriVox.org por Roberto Antonio Muñoz Fábula número 64 El lobo y la cruz A un lobo que comía un hueso, se le atragantó el hueso en la garganta y corría por todas partes en busca de auxilio. Encontró en su carrera a una grulla y le pidió que le salvara de aquella situación y que enseguida le pagaría por ello Aceptó la grulla e introdujo su cabeza en la boca del lobo, sacando de la garganta el hueso atravesado Pidió entonces la cancelación de la paga convenida Oye amiga, dijo el lobo ¿No crees que es suficiente paga con haber sacado tu cabeza sana y salva de mi boca? Nunca hagas favores a malvados, traficantes o corruptos, pues mucha paga tendrías si te dejan sano y salvo. Fin de fábula. Esta grabación es de dominio público. Gracias por ver el video.
#
#
#  21144-05.mp3:
#  Las fábulas de Sopo, grabado para LibriVox.org por Karen Savage Fábula número 65 El lobo y el caballo Pasaba un lobo por un sembrado de cebada, pero como no era comida de su gusto, la dejó y siguió su camino. Encontró al rato a un caballo Y le llevó al campo comentándole la gran cantidad de cebada que había hallado Pero que en vez de comérsela a él Mejor se la había dejado Porque le agradaba más oír el ruido de sus dientes al masticarla Pero el caballo le repuso Amigo, si los lobos comieran cebada no hubieras preferido complacer a tus oídos sino a tu estómago. A todo malvado, aunque parezca actuar como bueno, no debe de creérsele. Fin de fábula. Esta grabación es de dominio público.
#
#
#  21144-06.mp3:
#  Las fábulas de Esopo Grabado para LibriVox.org por Alejandro González Calderón Fábula número 66 El Lobo y el Asno Un lobo fue elegido rey entre sus congéneres y decretó una ley ordenando que lo que cada uno capturase en la casa lo pusiera en común y lo repartiese por partes iguales entre todos. De esta manera ya no tendrían los lobos que devorarse unos a otros en épocas de hambre. Pero en eso le escuchó un asno que estaba por ahí cerca y moviendo sus orejas le dijo Magnífica idea ha brotado de tu corazón Pero, ¿por qué has escondido todo tu botín en tu cueva Llevándolo a la comunidad y repártelo tan bien como lo has decretado? El lobo, descubierto y confundido, derogó su ley Si alguna vez llegas a tener poder de legislar Sé el primero en cumplir tus propias leyes Fin de la fábula Esta grabación es de dominio público
#
#
#  21144-14.mp3:
#  Las fábulas de Sopo Grabado para LibriVox.org por Elochito Fábula número 74 El lobo y el cabrito encerrado Protegido por la seguridad del corral de una casa, un cabrito vio pasar a un lobo y comenzó a insultarle burlándose ampliamente de él. El lobo serenamente le replicó Infeliz, sé que no eres tú quien me está insultando sino el sitio en que te encuentras. Muy a menudo no es el valor, sino la ocasión y el lugar quienes proveen el enfrentamiento arrogante ante los poderosos. Fin de la fábula. Esta grabación es del dominio público. Gracias por ver el video.
#
#
#  21144-22.mp3:
#  Las fábulas de Esopo Grabado para LibriVox.org por Elochito Fábula número 82 El perro y la almeja Un perro de esos acostumbrados a comer huevos, al ver una almeja, no lo pensó dos veces, y creyendo que se trataba de un huevo, se la tragó inmediatamente. Desgarradas luego sus entrañas, se sintió muy mal, y se dijo, bien merecido lo tengo, por creer que todo lo que veo redondo son huevos. Nunca tomes un asunto sin antes reflexionar, para no entrar luego en extrañas dificultades Fin de la fábula Esta grabación es del dominio público Gracias.
#
#
#  21144-24.mp3:
#  Las fábulas de Sopo Grabado para LibriVox.org por Karen Savage Fábula número 84 El perro y el reflejo en el río Badeaba un perro un río, llevando en su hocico un sabroso pedazo de carne. Vio su propio reflejo en el agua del río Y creyó que aquel reflejo era en realidad otro perro Que llevaba un trozo de carne mayor que el suyo Y deseando adueñarse del pedazo ajeno Soltó el suyo para arrebatar el trozo a su supuesto compadre Pero el resultado fue que se quedó sin el propio y sin el ajeno este porque no existía solo era un reflejo y el otro el verdadero porque se lo llevó a la corriente nunca codices el bien ajeno pues puedes perder lo que ya has adquirido con tu esfuerzo fin de fábula esta grabación es de dominio público Gracias por ver el video.
#
#
#  21144-25.mp3:
#  Las Fábulas de Esopo Grabado para LibreVox.org Fábula número 85 El perro y el carnicero Penetró un perro en una carnicería y notando que el carnicero estaba muy ocupado con sus clientes Cogió un trozo de carne y salió corriendo Se volvió el carnicero y viéndole huir Y sin poder hacer nada exclamó Oye amigo, allí donde te encuentre no dejaré de mirarte No esperes a que suceda un accidente para pensar en cómo evitarlo Fin de fábula Esta grabación es de dominio público
#
#
#  21144-26.mp3:
#  Las fábulas de Sopo Grabado para LibriVox.org por El Ochito Fábula número 86 El perro con campanilla Había un perro que acostumbraba a morder sin razón. Le puso su amo una campanilla para advertirle a la gente de su presencia cercana Y el can, sonando la campanilla, se fue a la plaza pública a presumir Mas una sabia perra, ya avanzada de años, le dijo ¿De qué presumes tanto, amigo? Sé que no llevas esa campanilla por tus grandes virtudes, sino para anunciar tu maldad oculta. Los halagos que se hacen a sí mismo los fanfarrones, sólo delatan sus mayores defectos. Fin de la fábula. Esta grabación es del dominio público. Gracias por ver el video.
#
#
#  21144-27.mp3:
#  Las fábulas de Esopo Grabado para LibriVox.org por Elo Chito Fábula número 87 El perro que perseguía al león Un perro de caza se encontró con un león y partió en su persecución. Pero el león se volvió rugiendo, y el perro, todo atemorizado, retrocedió rápidamente por el mismo camino. Le vio una zorra y le dijo, Perro infeliz, primero perseguías al león y ya ni siquiera soportas sus surgidos. Cuando entres a una empresa, mantente siempre listo a afrontar imprevistos que no te imaginabas Fin de la fábula Esta grabación es de iluminio público

# %% [markdown]
# # **Ejercicio 2b:**

# %% [markdown]
# * #### **Eliminar el inicio y final comunes de los textos extraídos de cada fábula.**
#
# * #### **Sugerencia:** Pueden guardar esta información en un archivo tipo JSON, para que al estar probando diferentes opciones en los ejercicios siguientes, puedan recuperar rápidamente la información de cada video/fábula.

# %%
# Funcion para limpiar la parte inicial y final de la fabula

import re

def limpiar_fabula(texto):
    patron = r"F[aá]bula n[uú]mero\s+\d+[^\w\n]*(.*?)(?=Fin de (la )?f[aá]bula|$)"

    match = re.search(patron, texto, re.IGNORECASE | re.DOTALL)

    if match:
        return match.group(1).strip()
    else:
        return ""

# %%
import json
# Escribir resultado en json
def escribir_json(datos, nombre_archivo):
  with open(nombre_archivo, "w", encoding="utf-8") as f:
    json.dump(datos, f, ensure_ascii=False, indent=2)

# Leer resultado de json
def leer_json(nombre_archivo):
  with open(nombre_archivo, "r", encoding="utf-8") as f:
    return json.load(f)

# %%
fabulas_limpias = {nombre: limpiar_fabula(texto) for nombre, texto in transcripciones.items()}

for nombre, fabula in fabulas_limpias.items():
    print(f"\n{nombre}:\n{fabula}\n")

escribir_json(fabulas_limpias, "fabulas_limpias.json")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6334cec09eae> in <cell line: 0>()
# ----> 1 fabulas_limpias = {nombre: limpiar_fabula(texto) for nombre, texto in transcripciones.items()}
#       2
#       3 for nombre, fabula in fabulas_limpias.items():
#       4     print(f"\n{nombre}:\n{fabula}\n")
#       5
#
# NameError: name 'transcripciones' is not defined

# %% [markdown]
# # **Ejercicio 3:**

# %% [markdown]
# * #### **Apliquen el proceso de limpieza que consideren adecuado.**
#
# * #### **Justifiquen los pasos de limpieza utilizados. Tomen en cuenta que el texto extraído de cada fábula es relativamente pequeño.**
#
# * #### **En caso de que decidan no aplicar esta etapa de limpieza, deberán justificarlo.**

# %% [markdown]
# #Justificación de limpieza
#
# Por lo visto en el contenido de las fábulas, son textos cortos y cada palabra carga con el significado del contexto en el que se encuentra.
#
# > En una iteración previa no realice un borrado de stopwords y me percaté que al realizar la obtención de las palabras clave por medio de LDA, muchos stop words estaban tomando reelevancia, lo que me dió a entender que no estaba bien el proceso de limpieza. Por ello, en esta siguiente iteración decidí ser un poco mas agresivo y eliminar stopwords en español.
#
#
# En ese sentido, considero debemos realizar una limpieza no agresiva, pero si considerada para evitar un mal calculo de palabras clave.
#
# Por ello decidí hacer lo siguiente:
# - Convertir todo el texto a minusculas
# - Quitar todo tipo de salto de linea, tabulación que no deba estar (es poco probable que exista, pero para tener un estandar lo consideré)
# - Borrar todos los caracteres que no sean alfanuméricos
# - Eliminar espacios multiples
# - Tokenizar el texto obtenido
# - Eliminar stop words en español

# %%
# Funciones de limpieza de texto
import re
import nltk
from nltk.corpus import stopwords
nltk.download('punkt_tab')
nltk.download('stopwords')

# Funcion responsable de limpiar las fabulas transcritas y tokenizarla al final de la limpieza
def limpiar_texto(texto):
  stopwords_es = set(stopwords.words('spanish'))
  texto = texto.lower()
  texto = re.sub(r'[\n\t\r]+', ' ', texto)
  texto = re.sub(r"[^a-zA-ZáéíóúÁÉÍÓÚñÑ0-9\s]", "", texto)
  texto = re.sub(r'\s{2,}', ' ', texto)
  tokens = nltk.word_tokenize(texto.strip(), language='spanish')
  tokens = [t.lower() for t in tokens if t.lower() not in stopwords_es]
  return tokens
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Limpiar y tokenizar las fabulas
fabulas_limpias = leer_json("fabulas_limpias.json")
fabulas_limpias_tokenizadas = {nombre: limpiar_texto(fabula) for nombre, fabula in fabulas_limpias.items()}

fabulas_limpias_tokenizadas.items()
# Out:
# dict_items([('21144-01.mp3', ['lobo', 'cordero', 'templo', 'dándose', 'cuenta', 'perseguido', 'lobo', 'pequeño', 'corderito', 'decidió', 'refugiarse', 'templo', 'cercano', 'llamó', 'lobo', 'dijo', 'si', 'sacrificador', 'encontraba', 'allí', 'adentro', 'inmolaría', 'dios', 'mejor', 'así', 'replicó', 'cordero', 'prefiero', 'ser', 'víctima', 'dios', 'tener', 'perecer', 'colmillos', 'si', 'remedio', 'vamos', 'ser', 'sacrificados', 'vale', 'mayor', 'honor']), ('21144-04.mp3', ['lobo', 'cruz', 'lobo', 'comía', 'hueso', 'atragantó', 'hueso', 'garganta', 'corría', 'todas', 'partes', 'busca', 'auxilio', 'encontró', 'carrera', 'grulla', 'pidió', 'salvara', 'aquella', 'situación', 'enseguida', 'pagaría', 'ello', 'aceptó', 'grulla', 'introdujo', 'cabeza', 'boca', 'lobo', 'sacando', 'garganta', 'hueso', 'atravesado', 'pidió', 'entonces', 'cancelación', 'paga', 'convenida', 'oye', 'amiga', 'dijo', 'lobo', 'crees', 'suficiente', 'paga', 'haber', 'sacado', 'cabeza', 'sana', 'salva', 'boca', 'nunca', 'hagas', 'favores', 'malvados', 'traficantes', 'corruptos', 'pues', 'mucha', 'paga', 'si', 'dejan', 'sano', 'salvo']), ('21144-05.mp3', ['lobo', 'caballo', 'pasaba', 'lobo', 'sembrado', 'cebada', 'comida', 'gusto', 'dejó', 'siguió', 'camino', 'encontró', 'rato', 'caballo', 'llevó', 'campo', 'comentándole', 'gran', 'cantidad', 'cebada', 'hallado', 'vez', 'comérsela', 'mejor', 'dejado', 'agradaba', 'oír', 'ruido', 'dientes', 'masticarla', 'caballo', 'repuso', 'amigo', 'si', 'lobos', 'comieran', 'cebada', 'preferido', 'complacer', 'oídos', 'sino', 'estómago', 'malvado', 'aunque', 'parezca', 'actuar', 'bueno', 'debe', 'creérsele']), ('21144-06.mp3', ['lobo', 'asno', 'lobo', 'elegido', 'rey', 'congéneres', 'decretó', 'ley', 'ordenando', 'cada', 'capturase', 'casa', 'pusiera', 'común', 'repartiese', 'partes', 'iguales', 'manera', 'lobos', 'devorarse', 'épocas', 'hambre', 'escuchó', 'asno', 'ahí', 'cerca', 'moviendo', 'orejas', 'dijo', 'magnífica', 'idea', 'brotado', 'corazón', 'escondido', 'botín', 'cueva', 'llevándolo', 'comunidad', 'repártelo', 'tan', 'bien', 'decretado', 'lobo', 'descubierto', 'confundido', 'derogó', 'ley', 'si', 'alguna', 'vez', 'llegas', 'tener', 'poder', 'legislar', 'sé', 'primero', 'cumplir', 'propias', 'leyes']), ('21144-14.mp3', ['lobo', 'cabrito', 'encerrado', 'protegido', 'seguridad', 'corral', 'casa', 'cabrito', 'vio', 'pasar', 'lobo', 'comenzó', 'insultarle', 'burlándose', 'ampliamente', 'lobo', 'serenamente', 'replicó', 'infeliz', 'sé', 'insultando', 'sino', 'sitio', 'encuentras', 'menudo', 'valor', 'sino', 'ocasión', 'lugar', 'proveen', 'enfrentamiento', 'arrogante', 'poderosos']), ('21144-22.mp3', ['perro', 'almeja', 'perro', 'acostumbrados', 'comer', 'huevos', 'ver', 'almeja', 'pensó', 'dos', 'veces', 'creyendo', 'trataba', 'huevo', 'tragó', 'inmediatamente', 'desgarradas', 'luego', 'entrañas', 'sintió', 'mal', 'dijo', 'bien', 'merecido', 'creer', 'veo', 'redondo', 'huevos', 'nunca', 'tomes', 'asunto', 'reflexionar', 'entrar', 'luego', 'extrañas', 'dificultades']), ('21144-24.mp3', ['perro', 'reflejo', 'río', 'badeaba', 'perro', 'río', 'llevando', 'hocico', 'sabroso', 'pedazo', 'carne', 'vio', 'propio', 'reflejo', 'agua', 'río', 'creyó', 'aquel', 'reflejo', 'realidad', 'perro', 'llevaba', 'trozo', 'carne', 'mayor', 'deseando', 'adueñarse', 'pedazo', 'ajeno', 'soltó', 'arrebatar', 'trozo', 'supuesto', 'compadre', 'resultado', 'quedó', 'propio', 'ajeno', 'existía', 'solo', 'reflejo', 'verdadero', 'llevó', 'corriente', 'nunca', 'codices', 'bien', 'ajeno', 'pues', 'puedes', 'perder', 'adquirido', 'esfuerzo']), ('21144-25.mp3', ['perro', 'carnicero', 'penetró', 'perro', 'carnicería', 'notando', 'carnicero', 'ocupado', 'clientes', 'cogió', 'trozo', 'carne', 'salió', 'corriendo', 'volvió', 'carnicero', 'viéndole', 'huir', 'poder', 'hacer', 'exclamó', 'oye', 'amigo', 'allí', 'encuentre', 'dejaré', 'mirarte', 'esperes', 'suceda', 'accidente', 'pensar', 'cómo', 'evitarlo']), ('21144-26.mp3', ['perro', 'campanilla', 'perro', 'acos ...

# %% [markdown]
# # **Ejercicio 4:**

# %%
# Incluyan a continuación todas las celdas (de código o texto) que deseen...
import gensim
import gensim.corpora as corpora

def CrearDicionarioYCorpus(fabulas_limpias_tokenizadas):
  # Crear diccionario
  diccionario = corpora.Dictionary(fabulas_limpias_tokenizadas.values())

  # Crear corpus
  corpus = [diccionario.doc2bow(tokens) for tokens in fabulas_limpias_tokenizadas.values()]

  return diccionario, corpus

# %%
# Crear modelo LDA
from gensim import models

diccionario, corpus = CrearDicionarioYCorpus(fabulas_limpias_tokenizadas)

lda_model = models.LdaModel(
    corpus=corpus,
    id2word=diccionario,
    num_topics=len(corpus),
    random_state=42,
    passes=10,
    per_word_topics=True
)

# Extraer palabras clave por fábula
palabras_clave_por_fabula = {}
for idx, topic in lda_model.show_topics(num_topics=len(corpus), num_words=20, formatted=False):
    palabras = [palabra for palabra, prob in topic]
    fabula_id = list(fabulas_limpias_tokenizadas.keys())[idx]
    palabras_clave_por_fabula[fabula_id] = palabras

# Mostrar resultado
for fabula, palabras in palabras_clave_por_fabula.items():
    print(f"\n{fabula}:\n - " + ", ".join(palabras))
# Out:
# 21144-01.mp3:
#  - reflejo, río, perro, ajeno, carne, trozo, propio, pedazo, bien, aquel, pues, soltó, puedes, agua, realidad, deseando, sabroso, corriente, creyó, resultado
#
# 21144-04.mp3:
#  - carnicero, lobo, perro, sino, cabrito, volvió, sé, amigo, infeliz, vio, accidente, esperes, mirarte, allí, encuentre, clientes, salió, dejaré, cogió, hacer
#
# 21144-05.mp3:
#  - perro, león, siquiera, volvió, perseguías, encontró, imaginabas, infeliz, soportas, vio, persecución, atemorizado, perseguía, listo, zorra, afrontar, mantente, dijo, rugiendo, retrocedió
#
# 21144-06.mp3:
#  - campanilla, perro, virtudes, mas, delatan, can, defectos, puso, halagos, presencia, mismo, avanzada, fanfarrones, plaza, sonando, cercana, advertirle, presumes, sólo, llevas
#
# 21144-14.mp3:
#  - campanilla, lobo, dijo, sé, asno, perro, ley, acostumbraba, amigo, si, plaza, oculta, amo, hacen, gente, fanfarrones, can, presumir, anunciar, partes
#
# 21144-22.mp3:
#  - lobo, perro, paga, nunca, casa, sino, bien, cabeza, cabrito, grulla, dijo, pidió, vio, boca, ley, partes, si, sé, almeja, hueso
#
# 21144-24.mp3:
#  - lobo, hueso, paga, huevos, luego, almeja, dijo, perro, garganta, cabeza, boca, nunca, pidió, grulla, dos, entrar, dificultades, creyendo, asunto, reflexionar
#
# 21144-25.mp3:
#  - lobo, si, dios, ser, cordero, templo, tener, dijo, encontraba, colmillos, mayor, mejor, cuenta, sacrificados, dándose, vale, vamos, víctima, decidió, así
#
# 21144-26.mp3:
#  - cebada, lobo, caballo, oír, rato, amigo, complacer, si, gusto, preferido, encontró, cantidad, dientes, lobos, mejor, sembrado, masticarla, comentándole, hallado, campo
#
# 21144-27.mp3:
#  - caballo, cebada, lobo, vez, lobos, si, comida, siguió, bueno, gran, malvado, agradaba, parezca, estómago, aunque, pasaba, dejado, oídos, repuso, sino

# %% [markdown]
# # **Ejercicio 5a y 5b:**

# %% [markdown]
# * #### **5a: Mediante el LLM que hayan seleccionado, generar un único enunciado que describa o resuma cada fábula.**
#
# * #### **5b: Mediante el LLM que hayan seleccionado, generar tres posibles enunciados diferentes relacionados con la historia de la fábula.**
#
# * #### **Sugerencia:** En realidad los dos incisos a y b se pueden obtener con un solo prompt que solicite la información y el formato correspondiente para cada una de estas partes. Por ejemplo, para cada fábula la salida puede ser un primer enunciado genérico que resume o describe dicha temática; seguido de tres enunciados, cada uno hablando sobre una situación o parte diferente de la fábula.

# %%
# Generar llamado a OpenAI para obtener el enunciado y los tres posibles enunciados
from google.colab import userdata
from openai import OpenAI
import openai

openaimodel="gpt-4-turbo"

# Metodo de realizar la conexión a openAI y retornar el cliente a utilizar
def ConectarOpenAI():
  api_key = userdata.get("openapikey")

  if not api_key:
    raise ValueError("API key no encontrada en los secretos")

  client = OpenAI(api_key = api_key)

  return client

def LlamaServicioOpenAI(client, prompt):
  try:
    response = client.chat.completions.create(
        model=openaimodel,
        messages=[
            {"role": "system", "content": "Eres un experto en análisis literario y resumen de textos."},
            {"role": "user", "content": prompt}
        ],
        temperature=0.7
    )
    texto_generado = response.choices[0].message.content.strip()
    return texto_generado

  except Exception as e:
    print(f"Error con {nombre_fabula}: {e}")
    return "ERROR"

# Este método se encarga de tomar las palabras claves y generar un enunciado principal
# y otros tres posibles enunciados relacionados a las palabras claves
def ObtenerEnunciadosFabulasDesdeOpenAI(palabras_clave):
  client = ConectarOpenAI()
  prompt = (
      f"Tengo esta lista de palabras clave sobre una fábula:\n"
      f"{', '.join(palabras_clave)}\n\n"
      "Vas a realizar la siguiente accion:\n"
      "1. A partir de estas palabras, genera UN enunciado breve que resuma el mensaje de la fábula.\n"
      "2. Luego, genera TRES posibles subtemas distintos relacionados con el contenido de la fábula.\n"
      "El formato será el siguiente:\n"
      "Enunciado principal:\n"
      "Enunciado 1:\n"
      "Enunciado 2:\n"
      "Enunciado 3:\n"
      "No agreges mas enunciados ni quites. No agreges texto adicional a la respuesta.\n"
  )

  return LlamaServicioOpenAI(client, prompt)


# Este método se encarga de tomar los enunciados generados y compararlo
# con el tema de la fabula original
# retorna un procentaje de exactitud
def CompararEnunciadosConFabula(fabula, palabras_clave):
  client = ConectarOpenAI()
  print(f"\nFabula:\n{fabula}\n\nPalabras clave:\n{palabras_clave}")
  prompt = (
      f"Esta es la fábula:\n"
      f"{fabula}\n\n"
      "Y estos son los enunciados obtenidos en base a una lista de palabras claves:\n"
      f"{', '.join(palabras_clave)}\n\n"
      "Vas a realizar la siguiente accion:\n"
      "Vas a evaluar cada enunciado en base al contenido de la fabula y vas a calcular un porcentaje de precisión.\n"
      "Al final agregaras unos comentarios de cuales fueron las razones de la diferencia entre el enunciado y la fábula"
      "El formato será el siguiente:\n"
      "EP: XX%\n"
      "E1: XX%\n"
      "E2: XX%\n"
      "E3: XX%\n"
      "Balance General: XX%"
      "Comentarios:"
      "No agreges mas información de la descrita en el formato.\n"
  )

  return LlamaServicioOpenAI(client, prompt)

# %%
# Llamar funciones para generar los enunciados
enunciados_por_fabula = {}
for nombre_fabula, palabras in palabras_clave_por_fabula.items():
  enunciados_por_fabula[nombre_fabula] = ObtenerEnunciadosFabulasDesdeOpenAI(palabras)
  print(f"{nombre_fabula}:\n{enunciados_por_fabula[nombre_fabula]}\n")
# Out:
# 21144-01.mp3:
# Enunciado principal: Al desear el reflejo de un trozo de carne en el agua, el perro soltó el que llevaba en su boca, perdiendo así lo propio por codiciar lo ajeno.
#
# Enunciado 1: La importancia de valorar lo que se posee en lugar de anhelar lo inalcanzable.
# Enunciado 2: Los engaños de la percepción y el impacto de la realidad en nuestras decisiones.
# Enunciado 3: Las consecuencias de la codicia y la pérdida por la ilusión de obtener más.
#
# 21144-04.mp3:
# Enunciado principal: El lobo disfrazado de carnicero engaña al perro y al cabrito, pero un accidente revela su verdadera identidad y ambos aprenden la importancia de no confiar en desconocidos.
#
# Enunciado 1: La astucia como herramienta de engaño y sus consecuencias.
# Enunciado 2: La importancia de la cautela y desconfianza hacia los extraños.
# Enunciado 3: El impacto de la verdad y cómo esta eventualmente sale a la luz.
#
# 21144-05.mp3:
# Enunciado principal: Mantente firme y listo para afrontar tus miedos, pues a veces lo que imaginas como una amenaza, puede no ser tan temible como creías.
#
# Enunciado 1: La importancia de enfrentar los miedos para superar las percepciones erróneas.
#
# Enunciado 2: El impacto de la imaginación en la percepción de peligros y amenazas.
#
# Enunciado 3: Cómo la valentía y la astucia pueden cambiar el curso de una persecución o conflicto.
#
# 21144-06.mp3:
# Enunciado principal: Los defectos no se ocultan con fanfarronerías, y a menudo, los halagos solo delatan nuestras verdaderas intenciones.
#
# Enunciado 1: La diferencia entre autoestima y arrogancia.
#
# Enunciado 2: El impacto de los halagos en la percepción de los demás.
#
# Enunciado 3: Cómo nuestros defectos pueden ser revelados en intentos de impresionar.
#
# 21144-14.mp3:
# Enunciado principal: Los fanfarrones que presumen en público suelen ser desenmascarados y ridiculizados.
#
# Enunciado 1: La falsa valentía y sus consecuencias en la sociedad.
#
# Enunciado 2: El impacto de la percepción pública en la conducta individual.
#
# Enunciado 3: La diferencia entre la autoestima y el exceso de confianza.
#
# 21144-22.mp3:
# Enunciado principal: La historia enseña que nunca se debe confiar plenamente en quien ha demostrado ser deshonesto, como el lobo que engaña al perro y al cabrito, y la grulla que, a pesar de ayudar, no recibe su recompensa.
#
# Enunciado 1: La importancia de la honestidad y la confianza en las relaciones.
# Enunciado 2: Las consecuencias de la codicia y el engaño.
# Enunciado 3: La justicia y la reciprocidad en las interacciones sociales.
#
# 21144-24.mp3:
# Enunciado principal: Reflexionar antes de actuar puede evitar dificultades y malentendidos innecesarios.
#
# Enunciado 1: La importancia de la prudencia en la toma de decisiones.
#
# Enunciado 2: Las consecuencias de la codicia y el egoísmo.
#
# Enunciado 3: La colaboración entre seres diferentes puede ser complicada pero beneficiosa.
#
# 21144-25.mp3:
# Enunciado principal: El lobo, al encontrarse con el cordero en el templo, decide que sería una víctima mejor y más valiosa para sacrificio, dándose cuenta de su poder.
#
# Enunciado 1: La manipulación del poderoso sobre el inocente.
# Enunciado 2: La selección de víctimas según la percepción de su valor.
# Enunciado 3: El rol de los lugares sagrados en decisiones morales.
#
# 21144-26.mp3:
# Enunciado principal: Un lobo intenta complacer a un caballo ofreciéndole cebada para ganarse su confianza y atacarlo, pero el caballo, sabio y cauteloso, reconoce la amenaza y evita la trampa.
#
# Enunciado 1: La importancia de la prudencia y desconfianza ante las ofertas engañosas.
#
# Enunciado 2: La astucia como herramienta de manipulación en las relaciones entre diferentes.
#
# Enunciado 3: El valor de la intuición y el juicio propio en la toma de decisiones.
#
# 21144-27.mp3:
# Enunciado principal: Aunque el caballo dejó comida para el lobo malvado con la esperanza de vivir en paz, el lobo siguió siendo una amenaza constante.
#
# Enunciado 1: La naturaleza inmutable de los instintos predatorios.
# Enunciado 2: Las consecuencias de confiar en individuos malintencionados.
# Enunciado 3: Estrategias fallidas de apaciguamiento frente a amenazas.

# %%
# Vamos a grabar los enunciados en un json
escribir_json(enunciados_por_fabula, "enunciados_por_fabula.json")

# %%
# Ahora vamos a comparar la fabula con los enunciados
# para saber que tan preciso fue el resultado en base a las palabras claves
enunciados_por_fabula = leer_json("enunciados_por_fabula.json")
fabulas_limpias = leer_json("fabulas_limpias.json")

# Llamar a OpenAI para evaluar la exactitud de los resultados
for nombre_fabula, fabula in fabulas_limpias.items():
  resultado = CompararEnunciadosConFabula(fabula, enunciados_por_fabula[nombre_fabula])
  print(f"{nombre_fabula}:\n{resultado}\n")
# Out:
# Fabula:
# El lobo y el cordero en el templo Dándose cuenta de que era perseguido por un lobo, un pequeño corderito decidió refugiarse en un templo cercano. Lo llamó lobo y le dijo que si el sacrificador lo encontraba allí adentro, lo inmolaría a su dios. Mejor así, replicó el cordero. Prefiero ser víctima para un dios a tener que perecer en tus colmillos. Si sin remedio vamos a ser sacrificados, más nos vale que sea con el mayor honor.
#
# Palabras clave:
# Enunciado principal: Al desear el reflejo de un trozo de carne en el agua, el perro soltó el que llevaba en su boca, perdiendo así lo propio por codiciar lo ajeno.
#
# Enunciado 1: La importancia de valorar lo que se posee en lugar de anhelar lo inalcanzable.
# Enunciado 2: Los engaños de la percepción y el impacto de la realidad en nuestras decisiones.
# Enunciado 3: Las consecuencias de la codicia y la pérdida por la ilusión de obtener más.
# 21144-01.mp3:
# EP: 0%
# E1: 0%
# E2: 0%
# E3: 0%
# Balance General: 0%
# Comentarios: Los enunciados no reflejan ni se relacionan con el contenido o tema de la fábula presentada.
#
#
# Fabula:
# El lobo y la cruz A un lobo que comía un hueso, se le atragantó el hueso en la garganta y corría por todas partes en busca de auxilio. Encontró en su carrera a una grulla y le pidió que le salvara de aquella situación y que enseguida le pagaría por ello Aceptó la grulla e introdujo su cabeza en la boca del lobo, sacando de la garganta el hueso atravesado Pidió entonces la cancelación de la paga convenida Oye amiga, dijo el lobo ¿No crees que es suficiente paga con haber sacado tu cabeza sana y salva de mi boca? Nunca hagas favores a malvados, traficantes o corruptos, pues mucha paga tendrías si te dejan sano y salvo.
#
# Palabras clave:
# Enunciado principal: El lobo disfrazado de carnicero engaña al perro y al cabrito, pero un accidente revela su verdadera identidad y ambos aprenden la importancia de no confiar en desconocidos.
#
# Enunciado 1: La astucia como herramienta de engaño y sus consecuencias.
# Enunciado 2: La importancia de la cautela y desconfianza hacia los extraños.
# Enunciado 3: El impacto de la verdad y cómo esta eventualmente sale a la luz.
# 21144-04.mp3:
# EP: 0%
# E1: 0%
# E2: 0%
# E3: 0%
# Balance General: 0%
# Comentarios: Los enunciados proporcionados no guardan relación con los eventos o temas de la fábula original "El lobo y la cruz". Esto resulta en una precisión del 0% para cada uno de ellos, ya que no reflejan ni el contenido ni el mensaje de la fábula analizada.
#
#
# Fabula:
# El lobo y el caballo Pasaba un lobo por un sembrado de cebada, pero como no era comida de su gusto, la dejó y siguió su camino. Encontró al rato a un caballo Y le llevó al campo comentándole la gran cantidad de cebada que había hallado Pero que en vez de comérsela a él Mejor se la había dejado Porque le agradaba más oír el ruido de sus dientes al masticarla Pero el caballo le repuso Amigo, si los lobos comieran cebada no hubieras preferido complacer a tus oídos sino a tu estómago. A todo malvado, aunque parezca actuar como bueno, no debe de creérsele.
#
# Palabras clave:
# Enunciado principal: Mantente firme y listo para afrontar tus miedos, pues a veces lo que imaginas como una amenaza, puede no ser tan temible como creías.
#
# Enunciado 1: La importancia de enfrentar los miedos para superar las percepciones erróneas.
#
# Enunciado 2: El impacto de la imaginación en la percepción de peligros y amenazas.
#
# Enunciado 3: Cómo la valentía y la astucia pueden cambiar el curso de una persecución o conflicto.
# 21144-05.mp3:
# EP: 0%
# E1: 0%
# E2: 0%
# E3: 0%
# Balance General: 0%
# Comentarios: Los enunciados no se relacionan directamente con el contenido o la moraleja de la fábula "El lobo y el caballo". La fábula se centra en la desconfianza hacia las intenciones de alguien conocido por actuar maliciosamente, mientras que los enunciados discuten conceptos generales sobre el miedo, la percepción y la valentía que no están específicamente vinculados a la trama o la lección de la fábula.
#
#
# Fabula:
# El Lobo y el Asno Un lobo fue elegido rey entre sus congéneres y decretó una ley ordenando que lo que cada uno capturase en la casa lo pusiera en común y lo repartiese por partes iguales entre todos. De esta manera ya no tendrían los lobos que devorarse unos a otros en épocas de hambre. Pero en eso le escuchó un asno que estaba por ahí cerca y moviendo sus orejas le dijo Magnífica idea ha brotado de tu corazón Pero, ¿por qué has escondido todo tu botín en tu cueva Llevándolo a la comunidad y repártelo tan bien como lo has decretado? El lobo, descubierto y confundido, derogó su ley Si alguna vez llegas a tener poder de legislar Sé el primero en cumplir tus propias leyes
#
# Palabras clave:
# Enunciado principal: Los defectos no se ocultan con fanfarronerías, y a menudo, los halagos solo delatan nuestras verdaderas intenciones.
#
# Enunciado 1: La diferencia entre autoestima y arrogancia.
#
# Enunciado 2: El impacto de los halagos en la percepción de los demás.
#
# Enunciado 3: Cómo nuestros defectos pueden ser revelados en intentos de impresionar.
# 21144-06.mp3:
# EP: 0%
# E1: 0%
# E2: 0%
# E3: 0%
# Balance General: 0%
# Comentarios: Los enunciados no reflejan el contenido ni la moraleja de la fábula del Lobo y el Asno, la cual trata sobre la hipocresía y la importancia de ser congruente con las leyes que uno establece. Los enunciados parecen estar desconectados temáticamente de la fábula original.
#
#
# Fabula:
# El lobo y el cabrito encerrado Protegido por la seguridad del corral de una casa, un cabrito vio pasar a un lobo y comenzó a insultarle burlándose ampliamente de él. El lobo serenamente le replicó Infeliz, sé que no eres tú quien me está insultando sino el sitio en que te encuentras. Muy a menudo no es el valor, sino la ocasión y el lugar quienes proveen el enfrentamiento arrogante ante los poderosos.
#
# Palabras clave:
# Enunciado principal: Los fanfarrones que presumen en público suelen ser desenmascarados y ridiculizados.
#
# Enunciado 1: La falsa valentía y sus consecuencias en la sociedad.
#
# Enunciado 2: El impacto de la percepción pública en la conducta individual.
#
# Enunciado 3: La diferencia entre la autoestima y el exceso de confianza.
# 21144-14.mp3:
# EP: 90%
# E1: 10%
# E2: 10%
# E3: 10%
# Balance General: 30%
#
# Comentarios:
# - EP refleja con alta precisión el tema central de la fábula, que trata sobre valentía y seguridad contextual por el lugar donde se encuentra el cabrito.
# - E1, E2 y E3 no se relacionan directamente con la trama o la moraleja de la fábula, ya que introducen conceptos como "falsa valentía", "impacto de la percepción pública" y "diferencia entre autoestima y exceso de confianza", que no están presentes en el texto original.
#
#
# Fabula:
# El perro y la almeja Un perro de esos acostumbrados a comer huevos, al ver una almeja, no lo pensó dos veces, y creyendo que se trataba de un huevo, se la tragó inmediatamente. Desgarradas luego sus entrañas, se sintió muy mal, y se dijo, bien merecido lo tengo, por creer que todo lo que veo redondo son huevos. Nunca tomes un asunto sin antes reflexionar, para no entrar luego en extrañas dificultades
#
# Palabras clave:
# Enunciado principal: La historia enseña que nunca se debe confiar plenamente en quien ha demostrado ser deshonesto, como el lobo que engaña al perro y al cabrito, y la grulla que, a pesar de ayudar, no recibe su recompensa.
#
# Enunciado 1: La importancia de la honestidad y la confianza en las relaciones.
# Enunciado 2: Las consecuencias de la codicia y el engaño.
# Enunciado 3: La justicia y la reciprocidad en las interacciones sociales.
# 21144-22.mp3:
# EP: 0%
# E1: 0%
# E2: 0%
# E3: 0%
# Balance General: 0%
# Comentarios: Los enunciados presentados no reflejan el contenido o la moraleja de la fábula "El perro y la almeja". La historia original habla sobre las consecuencias de no reflexionar antes de actuar, mientras que los enunciados discuten temas no relacionados como la honestidad, el engaño, y la reciprocidad en las interacciones sociales, los cuales no están presentes en la fábula.
#
#
# Fabula:
# El perro y el reflejo en el río Badeaba un perro un río, llevando en su hocico un sabroso pedazo de carne. Vio su propio reflejo en el agua del río Y creyó que aquel reflejo era en realidad otro perro Que llevaba un trozo de carne mayor que el suyo Y deseando adueñarse del pedazo ajeno Soltó el suyo para arrebatar el trozo a su supuesto compadre Pero el resultado fue que se quedó sin el propio y sin el ajeno este porque no existía solo era un reflejo y el otro el verdadero porque se lo llevó a la corriente nunca codices el bien ajeno pues puedes perder lo que ya has adquirido con tu esfuerzo
#
# Palabras clave:
# Enunciado principal: Reflexionar antes de actuar puede evitar dificultades y malentendidos innecesarios.
#
# Enunciado 1: La importancia de la prudencia en la toma de decisiones.
#
# Enunciado 2: Las consecuencias de la codicia y el egoísmo.
#
# Enunciado 3: La colaboración entre seres diferentes puede ser complicada pero beneficiosa.
# 21144-24.mp3:
# EP: 70%
# E1: 90%
# E2: 80%
# E3: 10%
# Balance General: 63%
# Comentarios:
# EP: La reflexión antes de actuar está implícita en la moraleja de la fábula, pero la fábula se centra más en la codicia y sus consecuencias que en las "dificultades y malentendidos innecesarios".
# E1: La importancia de la prudencia en la toma de decisiones está muy alineada con la moraleja de no codiciar lo ajeno y pensar bien antes de actuar, lo que justifica una alta precisión.
# E2: La codicia y el egoísmo son temas centrales en la fábula, lo que está bien reflejado en este enunciado aunque se enfoca más en la codicia que en el egoísmo directamente.
# E3: La colaboración entre seres diferentes no es un tema tratado en la fábula, lo que resulta en una baja precisión para este enunciado.
#
#
# Fabula:
# El perro y el carnicero Penetró un perro en una carnicería y notando que el carnicero estaba muy ocupado con sus clientes Cogió un trozo de carne y salió corriendo Se volvió el carnicero y viéndole huir Y sin poder hacer nada exclamó Oye amigo, allí donde te encuentre no dejaré de mirarte No esperes a que suceda un accidente para pensar en cómo evitarlo
#
# Palabras clave:
# Enunciado principal: El lobo, al encontrarse con el cordero en el templo, decide que sería una víctima mejor y más valiosa para sacrificio, dándose cuenta de su poder.
#
# Enunciado 1: La manipulación del poderoso sobre el inocente.
# Enunciado 2: La selección de víctimas según la percepción de su valor.
# Enunciado 3: El rol de los lugares sagrados en decisiones morales.
# 21144-25.mp3:
# EP: 0%
# E1: 0%
# E2: 0%
# E3: 0%
# Balance General: 0%
# Comentarios: Los enunciados no reflejan la trama de la fábula, que trata sobre un perro que roba carne en una carnicería y la reacción del carnicero. Los enunciados parecen pertenecer a una historia diferente que involucra temas de sacrificio, manipulación del poder y roles de lugares sagrados en decisiones morales, los cuales no están presentes en la fábula proporcionada.
#
#
# Fabula:
# El perro con campanilla Había un perro que acostumbraba a morder sin razón. Le puso su amo una campanilla para advertirle a la gente de su presencia cercana Y el can, sonando la campanilla, se fue a la plaza pública a presumir Mas una sabia perra, ya avanzada de años, le dijo ¿De qué presumes tanto, amigo? Sé que no llevas esa campanilla por tus grandes virtudes, sino para anunciar tu maldad oculta. Los halagos que se hacen a sí mismo los fanfarrones, sólo delatan sus mayores defectos.
#
# Palabras clave:
# Enunciado principal: Un lobo intenta complacer a un caballo ofreciéndole cebada para ganarse su confianza y atacarlo, pero el caballo, sabio y cauteloso, reconoce la amenaza y evita la trampa.
#
# Enunciado 1: La importancia de la prudencia y desconfianza ante las ofertas engañosas.
#
# Enunciado 2: La astucia como herramienta de manipulación en las relaciones entre diferentes.
#
# Enunciado 3: El valor de la intuición y el juicio propio en la toma de decisiones.
# 21144-26.mp3:
# EP: 0%
# E1: 0%
# E2: 0%
# E3: 0%
# Balance General: 0%
# Comentarios: Ninguno de los enunciados refleja la trama o la moraleja de la fábula original sobre el perro con campanilla y su comportamiento que alerta a los demás de su peligrosidad, evidenciando que el autoelogio puede revelar defectos ocultos. Los enunciados parecen pertenecer a otro texto que habla de lobos, caballos y manipulaciones, no relacionados con la fábula proporcionada.
#
#
# Fabula:
# El perro que perseguía al león Un perro de caza se encontró con un león y partió en su persecución. Pero el león se volvió rugiendo, y el perro, todo atemorizado, retrocedió rápidamente por el mismo camino. Le vio una zorra y le dijo, Perro infeliz, primero perseguías al león y ya ni siquiera soportas sus surgidos. Cuando entres a una empresa, mantente siempre listo a afrontar imprevistos que no te imaginabas
#
# Palabras clave:
# Enunciado principal: Aunque el caballo dejó comida para el lobo malvado con la esperanza de vivir en paz, el lobo siguió siendo una amenaza constante.
#
# Enunciado 1: La naturaleza inmutable de los instintos predatorios.
# Enunciado 2: Las consecuencias de confiar en individuos malintencionados.
# Enunciado 3: Estrategias fallidas de apaciguamiento frente a amenazas.
# 21144-27.mp3:
# EP: 0%
# E1: 0%
# E2: 0%
# E3: 0%
# Balance General: 0%
# Comentarios: Ninguno de los enunciados refleja la trama o la moraleja de la fábula original sobre el perro y el león, por lo tanto, la precisión es del 0% para todos los enunciados.

# %% [markdown]
# # **Ejercicio 6:**

# %% [markdown]
# * #### **Incluyan sus conclusiones de la actividad audio-a-texto:**
#
#
#
# None

# %% [markdown]
# # **Fin de la actividad LDA y LMM: audio-a-texto**
